# %% [markdown]
# # Beta notebook
#
# Prose cells count as documentation, not as code.

# %%
import math

# A comment inside a code cell.
def area(r):
    return math.pi * r ** 2

print(area(2))

# %%
area(3)
# Out:
# 12.566370614359172
